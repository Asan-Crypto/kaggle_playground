# %% [markdown]
# ## Проект: прогнозирование количества продаж мерча каггла, в кагглском магазине, стране и в дате

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('Downloads/tabular-playground-series-jan-2022/train.csv')

# %%
# Посмотрим на то, как выглядит наш временной ряд
train
# Out:
#        row_id        date  country       store         product  num_sold
# 0           0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...         ...      ...         ...             ...       ...
# 26293   26293  2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294  2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295  2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296  2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297  2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
# [26298 rows x 6 columns]

# %%
valid = pd.read_csv('Downloads/tabular-playground-series-jan-2022/test.csv')

# %%
valid
# Out:
#       row_id        date  country       store         product
# 0      26298  2019-01-01  Finland  KaggleMart      Kaggle Mug
# 1      26299  2019-01-01  Finland  KaggleMart      Kaggle Hat
# 2      26300  2019-01-01  Finland  KaggleMart  Kaggle Sticker
# 3      26301  2019-01-01  Finland  KaggleRama      Kaggle Mug
# 4      26302  2019-01-01  Finland  KaggleRama      Kaggle Hat
# ...      ...         ...      ...         ...             ...
# 6565   32863  2019-12-31   Sweden  KaggleMart      Kaggle Hat
# 6566   32864  2019-12-31   Sweden  KaggleMart  Kaggle Sticker
# 6567   32865  2019-12-31   Sweden  KaggleRama      Kaggle Mug
# 6568   32866  2019-12-31   Sweden  KaggleRama      Kaggle Hat
# 6569   32867  2019-12-31   Sweden  KaggleRama  Kaggle Sticker
#
# [6570 rows x 5 columns]

# %%
# Посмотрим какие страны содержит датасет
train.country.unique()
# Out:
# array(['Finland', 'Norway', 'Sweden'], dtype=object)

# %%
# Посмотрим магазины каггла
train.store.unique()
# Out:
# array(['KaggleMart', 'KaggleRama'], dtype=object)

# %%
# Какие мерчы были проданы у каггла
train['product'].unique()
# Out:
# array(['Kaggle Mug', 'Kaggle Hat', 'Kaggle Sticker'], dtype=object)

# %%
# Размернось train и valid
train.shape, valid.shape
# Out:
# ((26298, 6), (6570, 5))

# %%
# Переводим дата и object в datetime
train.date=pd.to_datetime(train.date)
valid.date=pd.to_datetime(valid.date)

# %% [markdown]
# ###

# %% [markdown]
# #### Проведем небольшой EDA

# %%
train[train.country == 'Finland']
# Out:
#        row_id       date  country       store         product  num_sold
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3 2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4 2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...        ...      ...         ...             ...       ...
# 26281   26281 2018-12-31  Finland  KaggleMart      Kaggle Hat       822
# 26282   26282 2018-12-31  Finland  KaggleMart  Kaggle Sticker       238
# 26283   26283 2018-12-31  Finland  KaggleRama      Kaggle Mug       831
# 26284   26284 2018-12-31  Finland  KaggleRama      Kaggle Hat      1231
# 26285   26285 2018-12-31  Finland  KaggleRama  Kaggle Sticker       360
#
# [8766 rows x 6 columns]

# %%
train[(train.date.dt.month == 2) & (train.date.dt.day == 29)].index
# Out:
# Int64Index([7632, 7633, 7634, 7635, 7636, 7637, 7638, 7639, 7640, 7641, 7642,
#             7643, 7644, 7645, 7646, 7647, 7648, 7649],
#            dtype='int64')

# %%
train[(train.date.dt.month == 2) & (train.date.dt.day == 29)]
# Out:
#       row_id       date  country       store         product  num_sold
# 7632    7632 2016-02-29  Finland  KaggleMart      Kaggle Mug       178
# 7633    7633 2016-02-29  Finland  KaggleMart      Kaggle Hat       345
# 7634    7634 2016-02-29  Finland  KaggleMart  Kaggle Sticker        85
# 7635    7635 2016-02-29  Finland  KaggleRama      Kaggle Mug       297
# 7636    7636 2016-02-29  Finland  KaggleRama      Kaggle Hat       650
# 7637    7637 2016-02-29  Finland  KaggleRama  Kaggle Sticker       152
# 7638    7638 2016-02-29   Norway  KaggleMart      Kaggle Mug       315
# 7639    7639 2016-02-29   Norway  KaggleMart      Kaggle Hat       554
# 7640    7640 2016-02-29   Norway  KaggleMart  Kaggle Sticker       130
# 7641    7641 2016-02-29   Norway  KaggleRama      Kaggle Mug       524
# 7642    7642 2016-02-29   Norway  KaggleRama      Kaggle Hat       981
# 7643    7643 2016-02-29   Norway  KaggleRama  Kaggle Sticker       232
# 7644    7644 2016-02-29   Sweden  KaggleMart      Kaggle Mug       211
# 7645    7645 2016-02-29   Sweden  KaggleMart      Kaggle Hat       426
# 7646    7646 2016-02-29   Sweden  KaggleMart  Kaggle Sticker        90
# 7647    7647 2016-02-29   Sweden  KaggleRama      Kaggle Mug       349
# 7648    7648 2016-02-29   Sweden  KaggleRama      Kaggle Hat       773
# 7649    7649 2016-02-29   Sweden  KaggleRama  Kaggle Sticker       192

# %% [markdown]
# #### Данная функция делит дату на 6 фичей: год, месяц и т.д.

# %%
def preprop(train):
    train['Year'] = train.date.dt.year
    train['Month'] = train.date.dt.month
    train['Day'] = train.date.dt.day
    train['day_of_year'] = train.date.dt.day_of_year
    train['day_of_week'] = train.date.dt.day_of_week
    train['day_of_month'] = train.date.dt.days_in_month
    return train

# %%
train.country.unique()
# Out:
# array(['Finland', 'Norway', 'Sweden'], dtype=object)

# %% [markdown]
# ### Построим модель

# %%
# Предобработаем данные
train = preprop(train)
valid = preprop(valid)

# %%
train['product'].unique()
# Out:
# array(['Kaggle Mug', 'Kaggle Hat', 'Kaggle Sticker'], dtype=object)

# %%
# Преобразуем все категориальные признаки в числовые
train = pd.get_dummies(train)

# %%
valid = pd.get_dummies(valid)

# %%
train.drop({'store_KaggleRama'}, axis = 1, inplace = True)
valid.drop({'store_KaggleRama'}, axis = 1, inplace = True)

# %%
train
# Out:
#        row_id       date  num_sold  Year  Month  Day  day_of_year  \
# 0           0 2015-01-01       329  2015      1    1            1
# 1           1 2015-01-01       520  2015      1    1            1
# 2           2 2015-01-01       146  2015      1    1            1
# 3           3 2015-01-01       572  2015      1    1            1
# 4           4 2015-01-01       911  2015      1    1            1
# ...       ...        ...       ...   ...    ...  ...          ...
# 26293   26293 2018-12-31       823  2018     12   31          365
# 26294   26294 2018-12-31       250  2018     12   31          365
# 26295   26295 2018-12-31      1004  2018     12   31          365
# 26296   26296 2018-12-31      1441  2018     12   31          365
# 26297   26297 2018-12-31       388  2018     12   31          365
#
#        day_of_week  day_of_month  country_Finland  country_Norway  \
# 0                3            31                1               0
# 1                3            31                1               0
# 2                3            31                1               0
# 3                3            31                1               0
# 4                3            31                1               0
# ...            ...           ...              ...             ...
# 26293            0            31                0               0
# 26294            0            31                0               0
# 26295            0            31                0               0
# 26296            0            31                0               0
# 26297            0            31                0               0
#
#        country_Sweden  store_KaggleMart  product_Kaggle Hat  \
# 0                   0                 1                   0
# 1                   0                 1                   1
# 2                   0                 1                   0
# 3                   0                 0                   0
# 4                   0                 0                   1
# ...               ...               ...                 ...
# 26293               1                 1                   1
# 26294               1                 1                   0
# 26295               1                 0                   0
# 26296               1                 0                   1
# 26297               1                 0                   0
#
#        product_Kaggle Mug  product_Kaggle Sticker
# 0                       1                       0
# 1                       0                       0
# 2                       0                       1
# 3                       1                       0
# 4                       0                       0
# ...                   ...                     ...
# 26293                   0                       0
# 26294                   0                       1
# 26295                   1                       0
# 26296                   0                       0
# 26297                   0                       1
#
# [26298 rows x 16 columns]

# %%
# Отсортируем по дате, чтоб потом разделить на train и тест
train = train.sort_values(by = ['date'])

# %%
train
# Out:
#        row_id       date  num_sold  Year  Month  Day  day_of_year  \
# 0           0 2015-01-01       329  2015      1    1            1
# 17         17 2015-01-01       324  2015      1    1            1
# 16         16 2015-01-01      1195  2015      1    1            1
# 15         15 2015-01-01       706  2015      1    1            1
# 14         14 2015-01-01       175  2015      1    1            1
# ...       ...        ...       ...   ...    ...  ...          ...
# 26281   26281 2018-12-31       822  2018     12   31          365
# 26280   26280 2018-12-31       469  2018     12   31          365
# 26296   26296 2018-12-31      1441  2018     12   31          365
# 26287   26287 2018-12-31      1124  2018     12   31          365
# 26297   26297 2018-12-31       388  2018     12   31          365
#
#        day_of_week  day_of_month  country_Finland  country_Norway  \
# 0                3            31                1               0
# 17               3            31                0               0
# 16               3            31                0               0
# 15               3            31                0               0
# 14               3            31                0               0
# ...            ...           ...              ...             ...
# 26281            0            31                1               0
# 26280            0            31                1               0
# 26296            0            31                0               0
# 26287            0            31                0               1
# 26297            0            31                0               0
#
#        country_Sweden  store_KaggleMart  product_Kaggle Hat  \
# 0                   0                 1                   0
# 17                  1                 0                   0
# 16                  1                 0                   1
# 15                  1                 0                   0
# 14                  1                 1                   0
# ...               ...               ...                 ...
# 26281               0                 1                   1
# 26280               0                 1                   0
# 26296               1                 0                   1
# 26287               0                 1                   1
# 26297               1                 0                   0
#
#        product_Kaggle Mug  product_Kaggle Sticker
# 0                       1                       0
# 17                      0                       1
# 16                      0                       0
# 15                      1                       0
# 14                      0                       1
# ...                   ...                     ...
# 26281                   0                       0
# 26280                   1                       0
# 26296                   0                       0
# 26287                   0                       0
# 26297                   0                       1
#
# [26298 rows x 16 columns]

# %%
# 70 проц. на train и 30 процентов на тест
# Так как у нас временные ряды, делим на train и test именно таким образом. (Так мы можем обучим модель на предыдущих датах, чтоб он научился строить прогноз на будущих датах)
X_test = train[-int(train.shape[0] * 0.3):]
X_train = train[:-int(train.shape[0] * 0.3)]

# %%
X_test
# Out:
#        row_id       date  num_sold  Year  Month  Day  day_of_year  \
# 18397   18397 2017-10-19       273  2017     10   19          292
# 18398   18398 2017-10-19        90  2017     10   19          292
# 18399   18399 2017-10-19       347  2017     10   19          292
# 18400   18400 2017-10-19       444  2017     10   19          292
# 18401   18401 2017-10-19       148  2017     10   19          292
# ...       ...        ...       ...   ...    ...  ...          ...
# 26281   26281 2018-12-31       822  2018     12   31          365
# 26280   26280 2018-12-31       469  2018     12   31          365
# 26296   26296 2018-12-31      1441  2018     12   31          365
# 26287   26287 2018-12-31      1124  2018     12   31          365
# 26297   26297 2018-12-31       388  2018     12   31          365
#
#        day_of_week  day_of_month  country_Finland  country_Norway  \
# 18397            3            31                1               0
# 18398            3            31                1               0
# 18399            3            31                1               0
# 18400            3            31                1               0
# 18401            3            31                1               0
# ...            ...           ...              ...             ...
# 26281            0            31                1               0
# 26280            0            31                1               0
# 26296            0            31                0               0
# 26287            0            31                0               1
# 26297            0            31                0               0
#
#        country_Sweden  store_KaggleMart  product_Kaggle Hat  \
# 18397               0                 1                   1
# 18398               0                 1                   0
# 18399               0                 0                   0
# 18400               0                 0                   1
# 18401               0                 0                   0
# ...               ...               ...                 ...
# 26281               0                 1                   1
# 26280               0                 1                   0
# 26296               1                 0                   1
# 26287               0                 1                   1
# 26297               1                 0                   0
#
#        product_Kaggle Mug  product_Kaggle Sticker
# 18397                   0                       0
# 18398                   0                       1
# 18399                   1                       0
# 18400                   0                       0
# 18401                   0                       1
# ...                   ...                     ...
# 26281                   0                       0
# 26280                   1                       0
# 26296                   0                       0
# 26287                   0                       0
# 26297                   0                       1
#
# [7889 rows x 16 columns]

# %%
y_test = X_test.num_sold
y_train = X_train.num_sold

# %%
X_train
# Out:
#        row_id       date  num_sold  Year  Month  Day  day_of_year  \
# 0           0 2015-01-01       329  2015      1    1            1
# 17         17 2015-01-01       324  2015      1    1            1
# 16         16 2015-01-01      1195  2015      1    1            1
# 15         15 2015-01-01       706  2015      1    1            1
# 14         14 2015-01-01       175  2015      1    1            1
# ...       ...        ...       ...   ...    ...  ...          ...
# 18413   18413 2017-10-19       190  2017     10   19          292
# 18404   18404 2017-10-19       168  2017     10   19          292
# 18402   18402 2017-10-19       295  2017     10   19          292
# 18403   18403 2017-10-19       428  2017     10   19          292
# 18396   18396 2017-10-19       187  2017     10   19          292
#
#        day_of_week  day_of_month  country_Finland  country_Norway  \
# 0                3            31                1               0
# 17               3            31                0               0
# 16               3            31                0               0
# 15               3            31                0               0
# 14               3            31                0               0
# ...            ...           ...              ...             ...
# 18413            3            31                0               0
# 18404            3            31                0               1
# 18402            3            31                0               1
# 18403            3            31                0               1
# 18396            3            31                1               0
#
#        country_Sweden  store_KaggleMart  product_Kaggle Hat  \
# 0                   0                 1                   0
# 17                  1                 0                   0
# 16                  1                 0                   1
# 15                  1                 0                   0
# 14                  1                 1                   0
# ...               ...               ...                 ...
# 18413               1                 0                   0
# 18404               0                 1                   0
# 18402               0                 1                   0
# 18403               0                 1                   1
# 18396               0                 1                   0
#
#        product_Kaggle Mug  product_Kaggle Sticker
# 0                       1                       0
# 17                      0                       1
# 16                      0                       0
# 15                      1                       0
# 14                      0                       1
# ...                   ...                     ...
# 18413                   0                       1
# 18404                   0                       1
# 18402                   1                       0
# 18403                   0                       0
# 18396                   1                       0
#
# [18409 rows x 16 columns]

# %%
X_train.drop({"row_id", "date", "num_sold"}, axis = 1, inplace=True)
X_test.drop({"row_id", "date", "num_sold"}, axis = 1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
valid.drop({"row_id", "date"}, axis = 1, inplace=True)

# %%
valid
# Out:
#       Year  Month  Day  day_of_year  day_of_week  day_of_month  \
# 0     2019      1    1            1            1            31
# 1     2019      1    1            1            1            31
# 2     2019      1    1            1            1            31
# 3     2019      1    1            1            1            31
# 4     2019      1    1            1            1            31
# ...    ...    ...  ...          ...          ...           ...
# 6565  2019     12   31          365            1            31
# 6566  2019     12   31          365            1            31
# 6567  2019     12   31          365            1            31
# 6568  2019     12   31          365            1            31
# 6569  2019     12   31          365            1            31
#
#       country_Finland  country_Norway  country_Sweden  store_KaggleMart  \
# 0                   1               0               0                 1
# 1                   1               0               0                 1
# 2                   1               0               0                 1
# 3                   1               0               0                 0
# 4                   1               0               0                 0
# ...               ...             ...             ...               ...
# 6565                0               0               1                 1
# 6566                0               0               1                 1
# 6567                0               0               1                 0
# 6568                0               0               1                 0
# 6569                0               0               1                 0
#
#       product_Kaggle Hat  product_Kaggle Mug  product_Kaggle Sticker
# 0                      0                   1                       0
# 1                      1                   0                       0
# 2                      0                   0                       1
# 3                      0                   1                       0
# 4                      1                   0                       0
# ...                  ...                 ...                     ...
# 6565                   1                   0                       0
# 6566                   0                   0                       1
# 6567                   0                   1                       0
# 6568                   1                   0                       0
# 6569                   0                   0                       1
#
# [6570 rows x 13 columns]

# %%
# Используем SMAPE в качестве метрики
def SMAPE(y_true, y_pred):
    denominator = (y_true + np.abs(y_pred)) / 200.0
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return np.round(np.mean(diff),5)

# %%
X_train
# Out:
#        Year  Month  Day  day_of_year  day_of_week  day_of_month  \
# 0      2015      1    1            1            3            31
# 17     2015      1    1            1            3            31
# 16     2015      1    1            1            3            31
# 15     2015      1    1            1            3            31
# 14     2015      1    1            1            3            31
# ...     ...    ...  ...          ...          ...           ...
# 18413  2017     10   19          292            3            31
# 18404  2017     10   19          292            3            31
# 18402  2017     10   19          292            3            31
# 18403  2017     10   19          292            3            31
# 18396  2017     10   19          292            3            31
#
#        country_Finland  country_Norway  country_Sweden  store_KaggleMart  \
# 0                    1               0               0                 1
# 17                   0               0               1                 0
# 16                   0               0               1                 0
# 15                   0               0               1                 0
# 14                   0               0               1                 1
# ...                ...             ...             ...               ...
# 18413                0               0               1                 0
# 18404                0               1               0                 1
# 18402                0               1               0                 1
# 18403                0               1               0                 1
# 18396                1               0               0                 1
#
#        product_Kaggle Hat  product_Kaggle Mug  product_Kaggle Sticker
# 0                       0                   1                       0
# 17                      0                   0                       1
# 16                      1                   0                       0
# 15                      0                   1                       0
# 14                      0                   0                       1
# ...                   ...                 ...                     ...
# 18413                   0                   0                       1
# 18404                   0                   0                       1
# 18402                   0                   1                       0
# 18403                   1                   0                       0
# 18396                   0                   1                       0
#
# [18409 rows x 13 columns]

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from lightgbm) (1.7.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from lightgbm) (1.20.3)
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (from lightgbm) (0.37.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\programdata\anaconda3\lib\site-packages (from lightgbm) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.2

# %%
# Попробуем обучить на нескольких моделях, чтобы в конце выбрать наилучшую
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import xgboost as xgb
import lightgbm as lgb

# %%
model = xgb.XGBRegressor()
model2 = lgb.LGBMRegressor()
gb = GradientBoostingRegressor(max_depth=5, learning_rate=0.9)
rf = RandomForestRegressor(max_depth=5)
lr = LinearRegression()

# %%
stack_regressor = StackingRegressor(estimators= [('rf', rf), ('gb', gb), ('xgb', model)], final_estimator= lgb.LGBMRegressor())

# %%
stack_regressor.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor(max_depth=5)),
#                               ('gb',
#                                GradientBoostingRegressor(learning_rate=0.9,
#                                                          max_depth=5)),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None, gamma=None,
#                                             gpu...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None,
#                                             reg_alpha=None, reg_lambda=None, ...))],
#                   final_estimator=LGBMRegressor())

# %%
SMAPE(y_test, stack_regressor.predict(X_test))
# Out:
# 8.81312

# %%
SMAPE(y_test, stack_regressor.predict(X_test))
# Out:
# 8.89791

# %%
stack_regressor.fit(train.drop({'date', 'num_sold', 'row_id'}, axis = 1), train.num_sold)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor(max_depth=5)),
#                               ('gb',
#                                GradientBoostingRegressor(learning_rate=0.9,
#                                                          max_depth=5)),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None, gamma=None,
#                                             gpu...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None,
#                                             reg_alpha=None, reg_lambda=None, ...)),
#                               ('lgb', LGBMRegressor())],
#                   final_estimator=LinearRegression())

# %%
y_valid = stack_regressor.predict(valid)

# %%
ans = pd.read_csv("sample_submission (1).csv")
ans.num_sold = y_valid

# %%
ans.to_csv("sample_submission.csv", index = False)

# %% [markdown]
# #### Попробуем теперь через train_test_split, проверим как она себя покажет

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop({'date', 'num_sold', 'row_id'}, axis = 1), train.num_sold, test_size = 0.25, random_state = 17)

# %%
stack_regressor.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor(max_depth=5)),
#                               ('gb',
#                                GradientBoostingRegressor(learning_rate=0.9,
#                                                          max_depth=5))])

# %%
SMAPE(y_test, stack_regressor.predict(X_test))
# Out:
# 6.00059

# %% [markdown]
# #### Здесь можно увидеть, что train_test_split для таких обработалась лучше

# %%
# Такс, вот этим методом все плохо
y_valid = stack_regressor.predict(valid)
ans = pd.read_csv("sample_submission (1).csv")
ans.num_sold = y_valid
ans.to_csv("sample_submission.csv", index = False)
